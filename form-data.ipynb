# %%
from typing import Annotated
from fastapi import FastAPI,Form

 app = FastAPI()

 # 安装uv pip install python-multipart

# %%
@app.post('/login/')
def login(username: Annotated[str,Form()],password: Annotated[str,Form()]):
    return {'username':username}
